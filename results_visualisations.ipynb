# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
# easy = {"Agent":["DQN","DQN","DQN","DQN","DQN","DDQN","DDQN","DDQN","DDQN","DDQN" ],
#         "Result":[18720, 14530.5, 2950000,427, 105.3, 28022, 28022, 1690000,28378,28378],
#         "Metric":["Maximum Score - Training", "Average Score - Training", "Training Iterations", "Maximum Score - Testing", "Average Score - Testing","Maximum Score - Training", "Average Score - Training", "Training Iterations", "Maximum Score - Testing", "Average Score - Testing"],
# }

easy = {"Agent":["DQN","DQN","DQN","DQN","DDQN","DDQN","DDQN","DDQN"],
        "Result":[18720, 14530.5,427, 105.3, 28022, 28022,28378,28378],
        "Metric":["Maximum Score - Training", "Average Score - Training", "Maximum Score - Testing", "Average Score - Testing","Maximum Score - Training", "Average Score - Training", "Maximum Score - Testing", "Average Score - Testing"],
}

# %%
moderate = {"Agent":["DQN","DQN","DQN","DQN","DDQN","DDQN","DDQN","DDQN"],
        "Result":[10092, 4567.33,2850, 1130.83, 13136, 5275.5,9311,746.078],
        "Metric":["Maximum Score - Training", "Average Score - Training", "Maximum Score - Testing", "Average Score - Testing","Maximum Score - Training", "Average Score - Training", "Maximum Score - Testing", "Average Score - Testing"],
}

# %%
hard = {"Agent":["DQN","DQN","DQN","DQN","DDQN","DDQN","DDQN","DDQN"],
        "Result":[204, 67.8,268, 125.52, 1878, 450.42,1796,770.36],
        "Metric":["Maximum Score - Training", "Average Score - Training", "Maximum Score - Testing", "Average Score - Testing","Maximum Score - Training", "Average Score - Training", "Maximum Score - Testing", "Average Score - Testing"],
}

# %%
general = {"Agent":["DQN","DQN","DQN","DQN","DDQN","DDQN","DDQN","DDQN"],
        "Result":[503, 93.18,418,109.5, 2396, 1023.16,553,168.66],
        "Metric":["Maximum Score - Training", "Average Score - Training", "Maximum Score - Testing", "Average Score - Testing","Maximum Score - Training", "Average Score - Training", "Maximum Score - Testing", "Average Score - Testing"],
}

# %%
training_iterations = {"Agent":["DQN","DQN","DQN","DQN","DDQN","DDQN","DDQN","DDQN"],
                       "Model":["easy","moderate","hard","general","easy","moderate","hard","general"],
                       "Training Iterations":[2950000,4320000,9220000,13140000,1690000,1470000,7740000,7520000]  
}

# %%
df_easy = pd.DataFrame(easy)
df_moderate = pd.DataFrame(moderate)
df_hard = pd.DataFrame(hard)
df_general = pd.DataFrame(general)
df_training_iterations = pd.DataFrame(training_iterations)
df_easy
# Out:
#   Agent   Result                    Metric
# 0   DQN  18720.0  Maximum Score - Training
# 1   DQN  14530.5  Average Score - Training
# 2   DQN    427.0   Maximum Score - Testing
# 3   DQN    105.3   Average Score - Testing
# 4  DDQN  28022.0  Maximum Score - Training
# 5  DDQN  28022.0  Average Score - Training
# 6  DDQN  28378.0   Maximum Score - Testing
# 7  DDQN  28378.0   Average Score - Testing

# %%
plt.figure(figsize = (7,5))
# sns.lineplot(x="Metric", y="Result", data = df_easy, hue = "Agent",style = "Agent", palette = "Accent_r", dashes = True, markers = ["o", "o"] )
sns.lineplot(x="Metric", y="Result", data = df_easy, hue = "Agent",style = "Agent", palette = "Accent_r", dashes = True, markers = ["o", "o"] )
# plt.title("Performance of DRL agents on easy model", fontsize = 13)
plt.xlabel("Model", fontsize = 10)
plt.ylabel("Results", fontsize = 10)
# chart.set_xticklabels(chart.get_xticklabels(), rotation=45, horizontalalignment='right')
plt.xticks(rotation=45, horizontalalignment='right', fontweight='light') 
plt.savefig("/content/drive/My Drive/Colab Notebooks/Dissertation/performance_easy.pdf", bbox_inches='tight')
plt.savefig("/content/drive/My Drive/Colab Notebooks/Dissertation/performance_easy.svg", bbox_inches='tight')
plt.show()

plt.figure(figsize = (7,5))
# sns.lineplot(x="Metric", y="Result", data = df_easy, hue = "Agent",style = "Agent", palette = "Accent_r", dashes = True, markers = ["o", "o"] )
sns.lineplot(x="Metric", y="Result", data = df_moderate, hue = "Agent",style = "Agent", palette = "Accent_r", dashes = True, markers = ["o", "o"] )
# plt.title("Performance of DRL agents on moderate model", fontsize = 13)
plt.xlabel("Model", fontsize = 10)
plt.ylabel("Results", fontsize = 10)
# chart.set_xticklabels(chart.get_xticklabels(), rotation=45, horizontalalignment='right')
plt.xticks(rotation=45, horizontalalignment='right', fontweight='light') 
plt.savefig("/content/drive/My Drive/Colab Notebooks/Dissertation/performance_moderate.pdf", bbox_inches='tight')
plt.savefig("/content/drive/My Drive/Colab Notebooks/Dissertation/performance_moderate.svg", bbox_inches='tight')
plt.show()

plt.figure(figsize = (7,5))
# sns.lineplot(x="Metric", y="Result", data = df_easy, hue = "Agent",style = "Agent", palette = "Accent_r", dashes = True, markers = ["o", "o"] )
sns.lineplot(x="Metric", y="Result", data = df_hard, hue = "Agent",style = "Agent", palette = "Accent_r", dashes = True, markers = ["o", "o"] )
# plt.title("Performance of DRL agents on hard model", fontsize = 13)
plt.xlabel("Model", fontsize = 10)
plt.ylabel("Results", fontsize = 10)
# chart.set_xticklabels(chart.get_xticklabels(), rotation=45, horizontalalignment='right')
plt.xticks(rotation=45, horizontalalignment='right', fontweight='light') 
plt.savefig("/content/drive/My Drive/Colab Notebooks/Dissertation/performance_hard.pdf", bbox_inches='tight')
plt.savefig("/content/drive/My Drive/Colab Notebooks/Dissertation/performance_hard.svg", bbox_inches='tight')
plt.show()

plt.figure(figsize = (7,5))
# sns.lineplot(x="Metric", y="Result", data = df_easy, hue = "Agent",style = "Agent", palette = "Accent_r", dashes = True, markers = ["o", "o"] )
sns.lineplot(x="Metric", y="Result", data = df_general, hue = "Agent",style = "Agent", palette = "Accent_r", dashes = True, markers = ["o", "o"] )
# plt.title("Performance of DRL agents on general model", fontsize = 13)
plt.xlabel("Model", fontsize = 10)
plt.ylabel("Results", fontsize = 10)
# chart.set_xticklabels(chart.get_xticklabels(), rotation=45, horizontalalignment='right')
plt.xticks(rotation=45, horizontalalignment='right', fontweight='light')
plt.savefig("/content/drive/My Drive/Colab Notebooks/Dissertation/performance_general.pdf", bbox_inches='tight')
plt.savefig("/content/drive/My Drive/Colab Notebooks/Dissertation/performance_general.svg", bbox_inches='tight')
plt.show()

# %%
plt.figure(figsize = (7,5))
sns.lineplot(x="Model", y="Training Iterations", data = df_training_iterations, hue = "Agent",style = "Agent", palette = "Accent_r", dashes = True, markers = ["o", "o"] )

# plt.title("Training iterations for DRL agents", fontsize = 13)
plt.xlabel("Model", fontsize = 10)
plt.ylabel("Training Iterations", fontsize = 10)
# chart.set_xticklabels(chart.get_xticklabels(), rotation=45, horizontalalignment='right')
plt.xticks(rotation=45, horizontalalignment='right', fontweight='light')
plt.savefig("/content/drive/My Drive/Colab Notebooks/Dissertation/training_iterations.pdf", bbox_inches='tight')
plt.savefig("/content/drive/My Drive/Colab Notebooks/Dissertation/training_iterations.svg", bbox_inches='tight')
plt.show()

# %%
# df_ddqn_general = pd.read_excel("/content/drive/My Drive/Colab Notebooks/Dissertation/ddqn_general_logs.xlsx")

# %%
df_general_training = pd.read_excel("/content/drive/My Drive/Colab Notebooks/Dissertation/general_model_output_logs.xlsx")

# %%
df_general_training.head()
# Out:
#    Timestep    State   Epsilon  Score  RandomActions Agent
# 0     10020  explore  0.099999      1           1015   DQN
# 1     10795  explore  0.099974      1           1099   DQN
# 2     11105  explore  0.099963      2           1140   DQN
# 3     11454  explore  0.099952      1           1189   DQN
# 4     11516  explore  0.099950      1           1195   DQN

# %%
df_general_training.describe
# Out:
# <bound method NDFrame.describe of        Timestep    State       Epsilon  Score  RandomActions Agent
# 0         10020  explore  9.999937e-02      1           1015   DQN
# 1         10795  explore  9.997356e-02      1           1099   DQN
# 2         11105  explore  9.996324e-02      2           1140   DQN
# 3         11454  explore  9.995162e-02      1           1189   DQN
# 4         11516  explore  9.994955e-02      1           1195   DQN
# ...         ...      ...           ...    ...            ...   ...
# 58047   7486685    train  1.924916e-05    623          56050  DDQN
# 58048   7489937    train  1.099557e-05     87          56050  DDQN
# 58049   7491882    train  7.156275e-06     51          56050  DDQN
# 58050   7500637    train  4.391436e-08    236          56050  DDQN
# 58051   7510771    train  1.259231e-05    273          56050  DDQN
#
# [58052 rows x 6 columns]>

# %%
df_general_dqn = df_general_training[df_general_training['Agent'] == 'DQN']
df_general_ddqn = df_general_training[df_general_training['Agent'] == 'DDQN']

# %%
# df_general_dqn = df_general_dqn.drop(['index'], axis=1)
df_general_dqn.reset_index(inplace=True,drop=True)
df_general_dqn.head()
# Out:
#    Timestep    State   Epsilon  Score  RandomActions Agent
# 0     10020  explore  0.099999      1           1015   DQN
# 1     10795  explore  0.099974      1           1099   DQN
# 2     11105  explore  0.099963      2           1140   DQN
# 3     11454  explore  0.099952      1           1189   DQN
# 4     11516  explore  0.099950      1           1195   DQN

# %%
# df_general_ddqn = df_general_ddqn.drop(['index'], axis=1)
df_general_ddqn.reset_index(inplace=True, drop=True)
df_general_ddqn.head()
# Out:
#    Timestep    State   Epsilon  Score  RandomActions Agent
# 0     10324  explore  0.096770      2            966  DDQN
# 1     10524  explore  0.094771      1            983  DDQN
# 2     10660  explore  0.093411      1           1004  DDQN
# 3     10777  explore  0.092241      1           1014  DDQN
# 4     10984  explore  0.090171      1           1035  DDQN

# %%
plt.figure(figsize = (10,5))
sns.lineplot(x="Timestep", y="Epsilon", data = df_general_ddqn, palette = "Accent_r", dashes = True, markers = ["o", "o"] )
# plt.title("Epsilon vs Training Iterations plot for DDQN agent in general model", fontsize = 13)
plt.xlabel("Training Iterations", fontsize = 10)
plt.ylabel("Epsilon", fontsize = 10)
# chart.set_xticklabels(chart.get_xticklabels(), rotation=45, horizontalalignment='right')
plt.xticks(rotation=45, horizontalalignment='right', fontweight='light')
plt.savefig("/content/drive/My Drive/Colab Notebooks/Dissertation/epsilon_vs_iterations_ddqn.pdf", bbox_inches='tight')
plt.savefig("/content/drive/My Drive/Colab Notebooks/Dissertation/epsilon_vs_iterations_ddqn.svg", bbox_inches='tight')
plt.show()

plt.figure(figsize = (10,5))
sns.lineplot(x="Timestep", y="Epsilon", data = df_general_dqn, palette = "Accent_r", dashes = True, markers = ["o", "o"] )
# plt.title("Epsilon vs Training Iterations plot for DQN agent in general model", fontsize = 13)
plt.xlabel("Training Iterations", fontsize = 10)
plt.ylabel("Epsilon", fontsize = 10)
# chart.set_xticklabels(chart.get_xticklabels(), rotation=45, horizontalalignment='right')
plt.xticks(rotation=45, horizontalalignment='right', fontweight='light')
plt.savefig("/content/drive/My Drive/Colab Notebooks/Dissertation/epsilon_vs_iterations_dqn.pdf", bbox_inches='tight')
plt.savefig("/content/drive/My Drive/Colab Notebooks/Dissertation/epsilon_vs_iterations_dqn.svg", bbox_inches='tight')
plt.show()

# %%
plt.figure(figsize = (10,5))
sns.lineplot(x="Timestep", y="Score", data = df_general_ddqn, palette = "Accent_r", dashes = True, markers = ["o", "o"] )
# plt.title("Score vs Training Iterations plot for DDQN agent in general model", fontsize = 13)
plt.xlabel("Training Iterations", fontsize = 10)
plt.ylabel("Score", fontsize = 10)
# chart.set_xticklabels(chart.get_xticklabels(), rotation=45, horizontalalignment='right')
plt.xticks(rotation=45, horizontalalignment='right', fontweight='light')
plt.savefig("/content/drive/My Drive/Colab Notebooks/Dissertation/score_vs_iterations_ddqn.pdf", bbox_inches='tight')
plt.savefig("/content/drive/My Drive/Colab Notebooks/Dissertation/score_vs_iterations_ddqn.svg", bbox_inches='tight')
plt.show()

plt.figure(figsize = (10,5))
sns.lineplot(x="Timestep", y="Score", data = df_general_dqn, palette = "Accent_r", dashes = True, markers = ["o", "o"] )
# plt.title("Score vs Training Iterations plot for DQN agent in general model", fontsize = 13)
plt.xlabel("Training Iterations", fontsize = 10)
plt.ylabel("Score", fontsize = 10)
# chart.set_xticklabels(chart.get_xticklabels(), rotation=45, horizontalalignment='right')
plt.xticks(rotation=45, horizontalalignment='right', fontweight='light')
plt.savefig("/content/drive/My Drive/Colab Notebooks/Dissertation/score_vs_iterations_dqn.pdf", bbox_inches='tight')
plt.savefig("/content/drive/My Drive/Colab Notebooks/Dissertation/score_vs_iterations_dqn.svg", bbox_inches='tight')
plt.show()

# %%
plt.figure(figsize = (15,6))
# sns.lineplot(x="Metric", y="Result", data = df_easy, hue = "Agent",style = "Agent", palette = "Accent_r", dashes = True, markers = ["o", "o"] )
sns.lineplot(x="Timestep", y="Score", data = df_general_training, hue = "Agent",style = "Agent", palette = "Accent_r", dashes = False, markers = ["o", "o"] )
# plt.title("Score vs Training Iterations plot for agents in general model", fontsize = 13)
plt.xlabel("Training Iterations", fontsize = 10)
plt.ylabel("Score", fontsize = 10)
# chart.set_xticklabels(chart.get_xticklabels(), rotation=45, horizontalalignment='right')
plt.xticks(rotation=45, horizontalalignment='right', fontweight='light')
plt.savefig("/content/drive/My Drive/Colab Notebooks/Dissertation/score_vs_iterations_comparison.pdf", bbox_inches='tight')
plt.savefig("/content/drive/My Drive/Colab Notebooks/Dissertation/score_vs_iterations_comparison.svg", bbox_inches='tight')
plt.show()

# %%
plt.figure(figsize = (10,5))
sns.lineplot(x="Timestep", y="RandomActions", data = df_general_ddqn, palette = "Accent_r", dashes = True, markers = ["o", "o"] )
# plt.title("Epsilon vs Training Iterations plot for DDQN agent in general model", fontsize = 13)
plt.xlabel("Training Iterations", fontsize = 10)
plt.ylabel("RandomActions", fontsize = 10)
# chart.set_xticklabels(chart.get_xticklabels(), rotation=45, horizontalalignment='right')
plt.xticks(rotation=45, horizontalalignment='right', fontweight='light')
plt.savefig("/content/drive/My Drive/Colab Notebooks/Dissertation/randomactions_vs_iterations_ddqn.pdf", bbox_inches='tight')
plt.savefig("/content/drive/My Drive/Colab Notebooks/Dissertation/randomactions_vs_iterations_ddqn.svg", bbox_inches='tight')
plt.show()

plt.figure(figsize = (10,5))
sns.lineplot(x="Timestep", y="RandomActions", data = df_general_dqn, palette = "Accent_r", dashes = True, markers = ["o", "o"] )
# plt.title("Epsilon vs Training Iterations plot for DQN agent in general model", fontsize = 13)
plt.xlabel("Training Iterations", fontsize = 10)
plt.ylabel("RandomActions", fontsize = 10)
# chart.set_xticklabels(chart.get_xticklabels(), rotation=45, horizontalalignment='right')
plt.xticks(rotation=45, horizontalalignment='right', fontweight='light')
plt.savefig("/content/drive/My Drive/Colab Notebooks/Dissertation/RandomActions_vs_iterations_dqn.pdf", bbox_inches='tight')
plt.savefig("/content/drive/My Drive/Colab Notebooks/Dissertation/RandomActions_vs_iterations_dqn.svg", bbox_inches='tight')
plt.show()

plt.figure(figsize = (15,6))
# sns.lineplot(x="Metric", y="Result", data = df_easy, hue = "Agent",style = "Agent", palette = "Accent_r", dashes = True, markers = ["o", "o"] )
sns.lineplot(x="Timestep", y="RandomActions", data = df_general_training, hue = "Agent",style = "Agent", palette = "Accent_r", dashes = False, markers = ["o", "o"] )
# plt.title("Score vs Training Iterations plot for agents in general model", fontsize = 13)
plt.xlabel("Training Iterations", fontsize = 10)
plt.ylabel("RandomActions", fontsize = 10)
# chart.set_xticklabels(chart.get_xticklabels(), rotation=45, horizontalalignment='right')
plt.xticks(rotation=45, horizontalalignment='right', fontweight='light')
plt.savefig("/content/drive/My Drive/Colab Notebooks/Dissertation/RandomActions_vs_iterations_comparison.pdf", bbox_inches='tight')
plt.savefig("/content/drive/My Drive/Colab Notebooks/Dissertation/RandomActions_vs_iterations_comparison.svg", bbox_inches='tight')
plt.show()

# %%
plt.figure(figsize = (7,5))
sns.lineplot(x="Epsilon", y="Score", data = df_general_ddqn, palette = "Accent_r", dashes = True, markers = ["o", "o"] )
# plt.title("Score vs Epsilon plot for DDQN agent", fontsize = 13)
plt.xlabel("Epsilon", fontsize = 10)
plt.ylabel("Score", fontsize = 10)
# chart.set_xticklabels(chart.get_xticklabels(), rotation=45, horizontalalignment='right')
plt.xticks(rotation=45, horizontalalignment='right', fontweight='light')
plt.savefig("/content/drive/My Drive/Colab Notebooks/Dissertation/score_vs_epsilon_ddqn.pdf", bbox_inches='tight')
plt.savefig("/content/drive/My Drive/Colab Notebooks/Dissertation/score_vs_epsilon_ddqn.svg", bbox_inches='tight')
plt.show()

plt.figure(figsize = (7,5))
sns.lineplot(x="Epsilon", y="Score", data = df_general_dqn, palette = "Accent_r", dashes = True, markers = ["o", "o"] )
# plt.title("Score vs Epsilon plot for DQN agent", fontsize = 13)
plt.xlabel("Epsilon", fontsize = 10)
plt.ylabel("Score", fontsize = 10)
# chart.set_xticklabels(chart.get_xticklabels(), rotation=45, horizontalalignment='right')
plt.xticks(rotation=45, horizontalalignment='right', fontweight='light')
plt.savefig("/content/drive/My Drive/Colab Notebooks/Dissertation/score_vs_epsilon_dqn.pdf", bbox_inches='tight')
plt.savefig("/content/drive/My Drive/Colab Notebooks/Dissertation/score_vs_epsilon_dqn.svg", bbox_inches='tight')
plt.show()
